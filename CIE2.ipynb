# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujajeeragal123/get2007/blob/main/CIE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/tips22.csv')
df
# Out:
#      rownames  total_bill   tip     sex smoker   day    time  size
# 0         1.0       16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         2.0       10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         3.0       21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         4.0       23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         5.0       24.59  3.61  Female     No   Sun  Dinner   4.0
# ..        ...         ...   ...     ...    ...   ...     ...   ...
# 239     240.0       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240     241.0       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241     242.0       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242     243.0       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243     244.0       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 8 columns]

# %%
df.head()
# Out:
#    rownames  total_bill   tip     sex smoker  day    time  size
# 0       1.0       16.99  1.01  Female     No  Sun  Dinner   2.0
# 1       2.0       10.34  1.66    Male     No  Sun  Dinner   3.0
# 2       3.0       21.01  3.50    Male     No  Sun  Dinner   3.0
# 3       4.0       23.68  3.31    Male     No  Sun  Dinner   2.0
# 4       5.0       24.59  3.61  Female     No  Sun  Dinner   4.0

# %%
df.tail()
# Out:
#      rownames  total_bill   tip     sex smoker   day    time  size
# 239     240.0       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240     241.0       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241     242.0       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242     243.0       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243     244.0       18.78  3.00  Female     No  Thur  Dinner   2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rownames    242 non-null    float64
#  1   total_bill  240 non-null    float64
#  2   tip         243 non-null    float64
#  3   sex         241 non-null    object
#  4   smoker      238 non-null    object
#  5   day         242 non-null    object
#  6   time        237 non-null    object
#  7   size        240 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 15.4+ KB

# %%
df.describe()
# Out:
#          rownames  total_bill         tip        size
# count  242.000000  240.000000  243.000000  240.000000
# mean   122.900826   19.716417    2.993909    2.579167
# std     70.708320    8.885203    1.384806    0.956143
# min      1.000000    3.070000    1.000000    1.000000
# 25%     62.250000   13.347500    2.000000    2.000000
# 50%    123.500000   17.685000    2.880000    2.000000
# 75%    183.750000   24.065000    3.530000    3.000000
# max    244.000000   50.810000   10.000000    6.000000

# %%
df.isnull().sum()
# Out:
# rownames      2
# total_bill    4
# tip           1
# sex           3
# smoker        6
# day           2
# time          7
# size          4
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv('/content/tips22.csv')
df.fillna(0)
print(df)
# Out:
#      rownames  total_bill   tip     sex smoker   day    time  size
# 0         1.0       16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         2.0       10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         3.0       21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         4.0       23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         5.0       24.59  3.61  Female     No   Sun  Dinner   4.0
# ..        ...         ...   ...     ...    ...   ...     ...   ...
# 239     240.0       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240     241.0       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241     242.0       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242     243.0       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243     244.0       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# rownames      2
# total_bill    4
# tip           1
# sex           3
# smoker        6
# day           2
# time          7
# size          4
# dtype: int64
